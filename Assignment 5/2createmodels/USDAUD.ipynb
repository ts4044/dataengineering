# %%
import csv

import numpy as np
import pandas as pd
from pycaret.regression import *

# %%
def substitute_values(data, sorted_index, prefix, column):
    sub = 1

    # This list stores the values at which the labels were changed
    divider_list = ["USDAUD", column]

    for i, index in enumerate(sorted_index):
        if i == 33:
            sub += 1
            divider_list.append(data.at[index, column])
        if i == 66:
            sub += 1
            divider_list.append(data.at[index, column])

        data.at[index, column] = (prefix * 10) + sub

    with open("../divider_list.csv", "a", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(divider_list)

    return data

# %%
data = pd.read_csv("../data/USDAUD.csv")

# Preprocessing

# Removing the first row since it is an outlier - return is 0
data = data.drop(data.index[0])

# Delete any rows with null values
data.dropna(inplace=True)

# Delete any rows with 0 Vol and 0 FD
data = data[data.vol != 0]
data = data[data.fd != 0]

# Multiply the returns column by 100000 to have a usable column
data.return_val *= 10000

# Resetting the indexes in the dataframe
data.reset_index(drop=True, inplace=True)

# Select only the required columns - mean, fd, vol, return
data = data[["mean", "vol", "fd", "return_val"]]

data.head(5)
# Out:
#        mean       vol            fd  return_val
# 0  1.480386  0.000873  9.149352e+05    0.357907
# 1  1.479257  0.001351  6.654915e+05   -7.627976
# 2  1.478147  0.001131  5.642829e+05   -7.499591
# 3  1.477415  0.000582  1.187293e+06   -4.955366
# 4  1.477271  0.000979  1.405563e+06   -0.972375

# %%
# Sorting the values independently as it worked the best
volatility_array = np.array(data["vol"])
# Argsort sorts the data and returns the indexes of the sorted values from original list
sorted_index = np.argsort(volatility_array)
# Using the sorted index positions, we can replace the values for
data = substitute_values(data, sorted_index, 0, "vol")

# Do the same actions for Fractal Dimension
fd_array = np.array(data["fd"])
sorted_index = np.argsort(fd_array)
data = substitute_values(data, sorted_index, 0, "fd")

data.head(5)
# Out:
#        mean  vol   fd  return_val
# 0  1.480386  2.0  2.0    0.357907
# 1  1.479257  3.0  1.0   -7.627976
# 2  1.478147  3.0  1.0   -7.499591
# 3  1.477415  1.0  3.0   -4.955366
# 4  1.477271  3.0  3.0   -0.972375

# %%
# Using PyCaret functions to setup the regression model trainer
regression = setup(data=data, target="return_val")
# Out:
# <style type="text/css">
# #T_eeb32_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eeb32_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeb32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eeb32_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_eeb32_row0_col1" class="data row0 col1" >5639</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eeb32_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_eeb32_row1_col1" class="data row1 col1" >return_val</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eeb32_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_eeb32_row2_col1" class="data row2 col1" >(139, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eeb32_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_eeb32_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eeb32_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_eeb32_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eeb32_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_eeb32_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eeb32_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_eeb32_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eeb32_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_eeb32_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eeb32_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_eeb32_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eeb32_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_eeb32_row9_col1" class="data row9 col1" >(97, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eeb32_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_eeb32_row10_col1" class="data row10 col1" >(42, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eeb32_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_eeb32_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eeb32_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_eeb32_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_eeb32_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_eeb32_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_eeb32_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_eeb32_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_eeb32_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_eeb32_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_eeb32_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_eeb32_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_eeb32_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_eeb32_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_eeb32_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_eeb32_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_eeb32_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_eeb32_row19_col1" class="data row19 col1" >030c</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_eeb32_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_eeb32_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_eeb32_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_eeb32_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_eeb32_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_eeb32_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_eeb32_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_eeb32_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_eeb32_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_eeb32_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_eeb32_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_eeb32_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_eeb32_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_eeb32_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_eeb32_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_eeb32_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_eeb32_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_eeb32_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_eeb32_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_eeb32_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeb32_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_eeb32_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_eeb32_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
# Compare the best models after training on different types
best = compare_models()
best
# Out:
# <style type="text/css">
# #T_d2bd2_ th {
#   text-align: left;
# }
# #T_d2bd2_row0_col0, #T_d2bd2_row0_col5, #T_d2bd2_row0_col6, #T_d2bd2_row1_col0, #T_d2bd2_row1_col1, #T_d2bd2_row1_col2, #T_d2bd2_row1_col3, #T_d2bd2_row1_col4, #T_d2bd2_row1_col5, #T_d2bd2_row1_col6, #T_d2bd2_row2_col0, #T_d2bd2_row2_col1, #T_d2bd2_row2_col2, #T_d2bd2_row2_col3, #T_d2bd2_row2_col4, #T_d2bd2_row2_col5, #T_d2bd2_row2_col6, #T_d2bd2_row3_col0, #T_d2bd2_row3_col1, #T_d2bd2_row3_col2, #T_d2bd2_row3_col3, #T_d2bd2_row3_col4, #T_d2bd2_row3_col5, #T_d2bd2_row3_col6, #T_d2bd2_row4_col0, #T_d2bd2_row4_col1, #T_d2bd2_row4_col2, #T_d2bd2_row4_col3, #T_d2bd2_row4_col4, #T_d2bd2_row4_col5, #T_d2bd2_row5_col0, #T_d2bd2_row5_col1, #T_d2bd2_row5_col2, #T_d2bd2_row5_col3, #T_d2bd2_row5_col4, #T_d2bd2_row5_col5, #T_d2bd2_row5_col6, #T_d2bd2_row6_col0, #T_d2bd2_row6_col1, #T_d2bd2_row6_col2, #T_d2bd2_row6_col3, #T_d2bd2_row6_col4, #T_d2bd2_row6_col5, #T_d2bd2_row6_col6, #T_d2bd2_row7_col0, #T_d2bd2_row7_col1, #T_d2bd2_row7_col2, #T_d2bd2_row7_col3, #T_d2bd2_row7_col4, #T_d2bd2_row7_col5, #T_d2bd2_row7_col6, #T_d2bd2_row8_col0, #T_d2bd2_row8_col1, #T_d2bd2_row8_col2, #T_d2bd2_row8_col3, #T_d2bd2_row8_col4, #T_d2bd2_row8_col5, #T_d2bd2_row8_col6, #T_d2bd2_row9_col0, #T_d2bd2_row9_col1, #T_d2bd2_row9_col2, #T_d2bd2_row9_col3, #T_d2bd2_row9_col4, #T_d2bd2_row9_col5, #T_d2bd2_row9_col6, #T_d2bd2_row10_col0, #T_d2bd2_row10_col1, #T_d2bd2_row10_col2, #T_d2bd2_row10_col3, #T_d2bd2_row10_col4, #T_d2bd2_row10_col5, #T_d2bd2_row10_col6, #T_d2bd2_row11_col0, #T_d2bd2_row11_col1, #T_d2bd2_row11_col2, #T_d2bd2_row11_col3, #T_d2bd2_row11_col4, #T_d2bd2_row11_col5, #T_d2bd2_row11_col6, #T_d2bd2_row12_col0, #T_d2bd2_row12_col1, #T_d2bd2_row12_col2, #T_d2bd2_row12_col3, #T_d2bd2_row12_col4, #T_d2bd2_row12_col5, #T_d2bd2_row12_col6, #T_d2bd2_row13_col0, #T_d2bd2_row13_col1, #T_d2bd2_row13_col2, #T_d2bd2_row13_col3, #T_d2bd2_row13_col4, #T_d2bd2_row13_col6, #T_d2bd2_row14_col0, #T_d2bd2_row14_col1, #T_d2bd2_row14_col2, #T_d2bd2_row14_col3, #T_d2bd2_row14_col4, #T_d2bd2_row14_col5, #T_d2bd2_row14_col6, #T_d2bd2_row15_col0, #T_d2bd2_row15_col1, #T_d2bd2_row15_col2, #T_d2bd2_row15_col3, #T_d2bd2_row15_col4, #T_d2bd2_row15_col5, #T_d2bd2_row15_col6, #T_d2bd2_row16_col0, #T_d2bd2_row16_col1, #T_d2bd2_row16_col2, #T_d2bd2_row16_col3, #T_d2bd2_row16_col4, #T_d2bd2_row16_col5, #T_d2bd2_row16_col6, #T_d2bd2_row17_col0, #T_d2bd2_row17_col1, #T_d2bd2_row17_col2, #T_d2bd2_row17_col3, #T_d2bd2_row17_col4, #T_d2bd2_row17_col5, #T_d2bd2_row17_col6 {
#   text-align: left;
# }
# #T_d2bd2_row0_col1, #T_d2bd2_row0_col2, #T_d2bd2_row0_col3, #T_d2bd2_row0_col4, #T_d2bd2_row4_col6, #T_d2bd2_row13_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d2bd2_row0_col7, #T_d2bd2_row1_col7, #T_d2bd2_row4_col7, #T_d2bd2_row5_col7, #T_d2bd2_row7_col7, #T_d2bd2_row8_col7, #T_d2bd2_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_d2bd2_row2_col7, #T_d2bd2_row3_col7, #T_d2bd2_row6_col7, #T_d2bd2_row10_col7, #T_d2bd2_row11_col7, #T_d2bd2_row12_col7, #T_d2bd2_row13_col7, #T_d2bd2_row14_col7, #T_d2bd2_row15_col7, #T_d2bd2_row16_col7, #T_d2bd2_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d2bd2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2bd2_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_d2bd2_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_d2bd2_row0_col1" class="data row0 col1" >4.2836</td>
#       <td id="T_d2bd2_row0_col2" class="data row0 col2" >70.8513</td>
#       <td id="T_d2bd2_row0_col3" class="data row0 col3" >6.4778</td>
#       <td id="T_d2bd2_row0_col4" class="data row0 col4" >-0.2766</td>
#       <td id="T_d2bd2_row0_col5" class="data row0 col5" >1.1107</td>
#       <td id="T_d2bd2_row0_col6" class="data row0 col6" >2.7167</td>
#       <td id="T_d2bd2_row0_col7" class="data row0 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d2bd2_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_d2bd2_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_d2bd2_row1_col1" class="data row1 col1" >4.3855</td>
#       <td id="T_d2bd2_row1_col2" class="data row1 col2" >71.6964</td>
#       <td id="T_d2bd2_row1_col3" class="data row1 col3" >6.5866</td>
#       <td id="T_d2bd2_row1_col4" class="data row1 col4" >-0.3456</td>
#       <td id="T_d2bd2_row1_col5" class="data row1 col5" >1.0389</td>
#       <td id="T_d2bd2_row1_col6" class="data row1 col6" >3.6342</td>
#       <td id="T_d2bd2_row1_col7" class="data row1 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d2bd2_level0_row2" class="row_heading level0 row2" >dummy</th>
#       <td id="T_d2bd2_row2_col0" class="data row2 col0" >Dummy Regressor</td>
#       <td id="T_d2bd2_row2_col1" class="data row2 col1" >4.3855</td>
#       <td id="T_d2bd2_row2_col2" class="data row2 col2" >71.6964</td>
#       <td id="T_d2bd2_row2_col3" class="data row2 col3" >6.5866</td>
#       <td id="T_d2bd2_row2_col4" class="data row2 col4" >-0.3456</td>
#       <td id="T_d2bd2_row2_col5" class="data row2 col5" >1.0389</td>
#       <td id="T_d2bd2_row2_col6" class="data row2 col6" >3.6342</td>
#       <td id="T_d2bd2_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_d2bd2_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_d2bd2_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_d2bd2_row3_col1" class="data row3 col1" >4.3621</td>
#       <td id="T_d2bd2_row3_col2" class="data row3 col2" >72.0959</td>
#       <td id="T_d2bd2_row3_col3" class="data row3 col3" >6.6186</td>
#       <td id="T_d2bd2_row3_col4" class="data row3 col4" >-0.3712</td>
#       <td id="T_d2bd2_row3_col5" class="data row3 col5" >1.0488</td>
#       <td id="T_d2bd2_row3_col6" class="data row3 col6" >2.4316</td>
#       <td id="T_d2bd2_row3_col7" class="data row3 col7" >0.2050</td>
#     </tr>
#     <tr>
#       <th id="T_d2bd2_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_d2bd2_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_d2bd2_row4_col1" class="data row4 col1" >4.3408</td>
#       <td id="T_d2bd2_row4_col2" class="data row4 col2" >72.0136</td>
#       <td id="T_d2bd2_row4_col3" class="data row4 col3" >6.6171</td>
#       <td id="T_d2bd2_row4_col4" class="data row4 col4" >-0.3737</td>
#       <td id="T_d2bd2_row4_col5" class="data row4 col5" >1.0550</td>
#       <td id="T_d2bd2_row4_col6" class="data row4 col6" >1.7707</td>
#       <td id="T_d2bd2_row4_col7" class="data row4 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d2bd2_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_d2bd2_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_d2bd2_row5_col1" class="data row5 col1" >4.3534</td>
#       <td id="T_d2bd2_row5_col2" class="data row5 col2" >72.6458</td>
#       <td id="T_d2bd2_row5_col3" class="data row5 col3" >6.6831</td>
#       <td id="T_d2bd2_row5_col4" class="data row5 col4" >-0.4227</td>
#       <td id="T_d2bd2_row5_col5" class="data row5 col5" >1.0430</td>
#       <td id="T_d2bd2_row5_col6" class="data row5 col6" >1.8313</td>
#       <td id="T_d2bd2_row5_col7" class="data row5 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_d2bd2_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_d2bd2_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_d2bd2_row6_col1" class="data row6 col1" >4.4797</td>
#       <td id="T_d2bd2_row6_col2"
# HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True, max_iter=100,
#                tol=1e-05, warm_start=False)

# %%
# Choose the best model technique and create a model
model = create_model(best)
# Out:
# <style type="text/css">
# #T_b16ce_row10_col0, #T_b16ce_row10_col1, #T_b16ce_row10_col2, #T_b16ce_row10_col3, #T_b16ce_row10_col4, #T_b16ce_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b16ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b16ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b16ce_row0_col0" class="data row0 col0" >3.5753</td>
#       <td id="T_b16ce_row0_col1" class="data row0 col1" >17.5176</td>
#       <td id="T_b16ce_row0_col2" class="data row0 col2" >4.1854</td>
#       <td id="T_b16ce_row0_col3" class="data row0 col3" >-0.2261</td>
#       <td id="T_b16ce_row0_col4" class="data row0 col4" >1.1119</td>
#       <td id="T_b16ce_row0_col5" class="data row0 col5" >1.5265</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b16ce_row1_col0" class="data row1 col0" >5.8084</td>
#       <td id="T_b16ce_row1_col1" class="data row1 col1" >114.5004</td>
#       <td id="T_b16ce_row1_col2" class="data row1 col2" >10.7005</td>
#       <td id="T_b16ce_row1_col3" class="data row1 col3" >-0.0699</td>
#       <td id="T_b16ce_row1_col4" class="data row1 col4" >1.3462</td>
#       <td id="T_b16ce_row1_col5" class="data row1 col5" >1.6129</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b16ce_row2_col0" class="data row2 col0" >10.7084</td>
#       <td id="T_b16ce_row2_col1" class="data row2 col1" >454.5288</td>
#       <td id="T_b16ce_row2_col2" class="data row2 col2" >21.3197</td>
#       <td id="T_b16ce_row2_col3" class="data row2 col3" >-0.2378</td>
#       <td id="T_b16ce_row2_col4" class="data row2 col4" >1.6279</td>
#       <td id="T_b16ce_row2_col5" class="data row2 col5" >1.1145</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b16ce_row3_col0" class="data row3 col0" >3.7568</td>
#       <td id="T_b16ce_row3_col1" class="data row3 col1" >21.5166</td>
#       <td id="T_b16ce_row3_col2" class="data row3 col2" >4.6386</td>
#       <td id="T_b16ce_row3_col3" class="data row3 col3" >-1.1035</td>
#       <td id="T_b16ce_row3_col4" class="data row3 col4" >1.2663</td>
#       <td id="T_b16ce_row3_col5" class="data row3 col5" >1.0387</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b16ce_row4_col0" class="data row4 col0" >3.1536</td>
#       <td id="T_b16ce_row4_col1" class="data row4 col1" >15.6047</td>
#       <td id="T_b16ce_row4_col2" class="data row4 col2" >3.9503</td>
#       <td id="T_b16ce_row4_col3" class="data row4 col3" >-0.0704</td>
#       <td id="T_b16ce_row4_col4" class="data row4 col4" >0.9663</td>
#       <td id="T_b16ce_row4_col5" class="data row4 col5" >1.5981</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b16ce_row5_col0" class="data row5 col0" >4.0069</td>
#       <td id="T_b16ce_row5_col1" class="data row5 col1" >29.2642</td>
#       <td id="T_b16ce_row5_col2" class="data row5 col2" >5.4096</td>
#       <td id="T_b16ce_row5_col3" class="data row5 col3" >-0.0961</td>
#       <td id="T_b16ce_row5_col4" class="data row5 col4" >1.1152</td>
#       <td id="T_b16ce_row5_col5" class="data row5 col5" >15.6529</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b16ce_row6_col0" class="data row6 col0" >3.2389</td>
#       <td id="T_b16ce_row6_col1" class="data row6 col1" >17.0223</td>
#       <td id="T_b16ce_row6_col2" class="data row6 col2" >4.1258</td>
#       <td id="T_b16ce_row6_col3" class="data row6 col3" >0.1412</td>
#       <td id="T_b16ce_row6_col4" class="data row6 col4" >1.0800</td>
#       <td id="T_b16ce_row6_col5" class="data row6 col5" >0.9663</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b16ce_row7_col0" class="data row7 col0" >3.7953</td>
#       <td id="T_b16ce_row7_col1" class="data row7 col1" >21.4901</td>
#       <td id="T_b16ce_row7_col2" class="data row7 col2" >4.6357</td>
#       <td id="T_b16ce_row7_col3" class="data row7 col3" >-0.3003</td>
#       <td id="T_b16ce_row7_col4" class="data row7 col4" >1.1338</td>
#       <td id="T_b16ce_row7_col5" class="data row7 col5" >1.0553</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b16ce_row8_col0" class="data row8 col0" >2.6939</td>
#       <td id="T_b16ce_row8_col1" class="data row8 col1" >10.2518</td>
#       <td id="T_b16ce_row8_col2" class="data row8 col2" >3.2018</td>
#       <td id="T_b16ce_row8_col3" class="data row8 col3" >-0.8780</td>
#       <td id="T_b16ce_row8_col4" class="data row8 col4" >0.6671</td>
#       <td id="T_b16ce_row8_col5" class="data row8 col5" >1.0603</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b16ce_row9_col0" class="data row9 col0" >2.0981</td>
#       <td id="T_b16ce_row9_col1" class="data row9 col1" >6.8159</td>
#       <td id="T_b16ce_row9_col2" class="data row9 col2" >2.6107</td>
#       <td id="T_b16ce_row9_col3" class="data row9 col3" >0.0748</td>
#       <td id="T_b16ce_row9_col4" class="data row9 col4" >0.7924</td>
#       <td id="T_b16ce_row9_col5" class="data row9 col5" >1.5409</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b16ce_row10_col0" class="data row10 col0" >4.2836</td>
#       <td id="T_b16ce_row10_col1" class="data row10 col1" >70.8513</td>
#       <td id="T_b16ce_row10_col2" class="data row10 col2" >6.4778</td>
#       <td id="T_b16ce_row10_col3" class="data row10 col3" >-0.2766</td>
#       <td id="T_b16ce_row10_col4" class="data row10 col4" >1.1107</td>
#       <td id="T_b16ce_row10_col5" class="data row10 col5" >2.7167</td>
#     </tr>
#     <tr>
#       <th id="T_b16ce_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b16ce_row11_col0" class="data row11 col0" >2.3317</td>
#       <td id="T_b16ce_row11_col1" class="data row11 col1" >131.2557</td>
#       <td id="T_b16ce_row11_col2" class="data row11 col2" >5.3749</td>
#       <td id="T_b16ce_row11_col3" class="data row11 col3" >0.3829</td>
#       <td id="T_b16ce_row11_col4" class="data row11 col4" >0.2584</td>
#       <td id="T_b16ce_row11_col5" class="data row11 col5" >4.3193</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Run model tune to get a better fit
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_fa078_row10_col0, #T_fa078_row10_col1, #T_fa078_row10_col2, #T_fa078_row10_col3, #T_fa078_row10_col4, #T_fa078_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fa078_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa078_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa078_row0_col0" class="data row0 col0" >3.5007</td>
#       <td id="T_fa078_row0_col1" class="data row0 col1" >16.8302</td>
#       <td id="T_fa078_row0_col2" class="data row0 col2" >4.1025</td>
#       <td id="T_fa078_row0_col3" class="data row0 col3" >-0.1779</td>
#       <td id="T_fa078_row0_col4" class="data row0 col4" >1.0978</td>
#       <td id="T_fa078_row0_col5" class="data row0 col5" >1.6274</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa078_row1_col0" class="data row1 col0" >5.8674</td>
#       <td id="T_fa078_row1_col1" class="data row1 col1" >114.2996</td>
#       <td id="T_fa078_row1_col2" class="data row1 col2" >10.6911</td>
#       <td id="T_fa078_row1_col3" class="data row1 col3" >-0.0680</td>
#       <td id="T_fa078_row1_col4" class="data row1 col4" >1.3575</td>
#       <td id="T_fa078_row1_col5" class="data row1 col5" >1.7545</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa078_row2_col0" class="data row2 col0" >10.8153</td>
#       <td id="T_fa078_row2_col1" class="data row2 col1" >458.3354</td>
#       <td id="T_fa078_row2_col2" class="data row2 col2" >21.4088</td>
#       <td id="T_fa078_row2_col3" class="data row2 col3" >-0.2481</td>
#       <td id="T_fa078_row2_col4" class="data row2 col4" >1.5519</td>
#       <td id="T_fa078_row2_col5" class="data row2 col5" >1.1403</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa078_row3_col0" class="data row3 col0" >3.6258</td>
#       <td id="T_fa078_row3_col1" class="data row3 col1" >20.5119</td>
#       <td id="T_fa078_row3_col2" class="data row3 col2" >4.5290</td>
#       <td id="T_fa078_row3_col3" class="data row3 col3" >-1.0053</td>
#       <td id="T_fa078_row3_col4" class="data row3 col4" >1.2460</td>
#       <td id="T_fa078_row3_col5" class="data row3 col5" >0.9294</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa078_row4_col0" class="data row4 col0" >3.1795</td>
#       <td id="T_fa078_row4_col1" class="data row4 col1" >16.0042</td>
#       <td id="T_fa078_row4_col2" class="data row4 col2" >4.0005</td>
#       <td id="T_fa078_row4_col3" class="data row4 col3" >-0.0978</td>
#       <td id="T_fa078_row4_col4" class="data row4 col4" >0.8466</td>
#       <td id="T_fa078_row4_col5" class="data row4 col5" >1.6850</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa078_row5_col0" class="data row5 col0" >3.9826</td>
#       <td id="T_fa078_row5_col1" class="data row5 col1" >29.0635</td>
#       <td id="T_fa078_row5_col2" class="data row5 col2" >5.3911</td>
#       <td id="T_fa078_row5_col3" class="data row5 col3" >-0.0885</td>
#       <td id="T_fa078_row5_col4" class="data row5 col4" >1.0943</td>
#       <td id="T_fa078_row5_col5" class="data row5 col5" >14.3689</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa078_row6_col0" class="data row6 col0" >3.2386</td>
#       <td id="T_fa078_row6_col1" class="data row6 col1" >17.1312</td>
#       <td id="T_fa078_row6_col2" class="data row6 col2" >4.1390</td>
#       <td id="T_fa078_row6_col3" class="data row6 col3" >0.1357</td>
#       <td id="T_fa078_row6_col4" class="data row6 col4" >1.0384</td>
#       <td id="T_fa078_row6_col5" class="data row6 col5" >0.9504</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa078_row7_col0" class="data row7 col0" >3.7543</td>
#       <td id="T_fa078_row7_col1" class="data row7 col1" >21.0179</td>
#       <td id="T_fa078_row7_col2" class="data row7 col2" >4.5845</td>
#       <td id="T_fa078_row7_col3" class="data row7 col3" >-0.2717</td>
#       <td id="T_fa078_row7_col4" class="data row7 col4" >1.0904</td>
#       <td id="T_fa078_row7_col5" class="data row7 col5" >1.0209</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa078_row8_col0" class="data row8 col0" >2.6580</td>
#       <td id="T_fa078_row8_col1" class="data row8 col1" >10.2211</td>
#       <td id="T_fa078_row8_col2" class="data row8 col2" >3.1970</td>
#       <td id="T_fa078_row8_col3" class="data row8 col3" >-0.8724</td>
#       <td id="T_fa078_row8_col4" class="data row8 col4" >0.5511</td>
#       <td id="T_fa078_row8_col5" class="data row8 col5" >1.0476</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa078_row9_col0" class="data row9 col0" >2.1316</td>
#       <td id="T_fa078_row9_col1" class="data row9 col1" >6.7348</td>
#       <td id="T_fa078_row9_col2" class="data row9 col2" >2.5951</td>
#       <td id="T_fa078_row9_col3" class="data row9 col3" >0.0858</td>
#       <td id="T_fa078_row9_col4" class="data row9 col4" >0.7461</td>
#       <td id="T_fa078_row9_col5" class="data row9 col5" >1.6931</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fa078_row10_col0" class="data row10 col0" >4.2754</td>
#       <td id="T_fa078_row10_col1" class="data row10 col1" >71.0150</td>
#       <td id="T_fa078_row10_col2" class="data row10 col2" >6.4639</td>
#       <td id="T_fa078_row10_col3" class="data row10 col3" >-0.2608</td>
#       <td id="T_fa078_row10_col4" class="data row10 col4" >1.0620</td>
#       <td id="T_fa078_row10_col5" class="data row10 col5" >2.6217</td>
#     </tr>
#     <tr>
#       <th id="T_fa078_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fa078_row11_col0" class="data row11 col0" >2.3701</td>
#       <td id="T_fa078_row11_col1" class="data row11 col1" >132.4365</td>
#       <td id="T_fa078_row11_col2" class="data row11 col2" >5.4068</td>
#       <td id="T_fa078_row11_col3" class="data row11 col3" >0.3614</td>
#       <td id="T_fa078_row11_col4" class="data row11 col4" >0.2779</td>
#       <td id="T_fa078_row11_col5" class="data row11 col5" >3.9290</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Mark the tuned model as final and save it
model = finalize_model(model)
save_model(model, "../models/USDAUD")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='return_val', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strat...
#                  ('dummy', Dummify(target='return_val')),
#                  ('fix_perfect', Remove_100(target='return_val')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True,
#                                  max_iter=100, tol=1e-05, warm_start=False)]],
#           verbose=False),
#  '../models/USDAUD.pkl')
